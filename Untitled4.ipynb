# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
df1=pd.read_csv('Sondaggio01.csv')

# %%
df1
# Out:
#     minaccia      MODALITA'          LOCALITA'  LATITUDINE LONGITUDINE
# 0        0.1     VITA REALE            Salerno   40.395112   14.481656
# 1        1.0     VITA REALE            Ravenna    44.25444   12.115892
# 2        1.0     VITA REALE            Ravenna    44.25444   12.115892
# 3        0.5     VITA REALE            Ravenna    44.25444   12.115892
# 4        0.1     VITA REALE            Ravenna    44.25444   12.115892
# 5        0.1  VITA VIRTUALE            Ravenna    44.25444   12.115892
# 6        0.1  VITA VIRTUALE             Lipomo     45.4738     9.10534
# 7        1.0     VITA REALE               Como   45.483924    ‎9.51860
# 8        0.1  VITA VIRTUALE               Como   45.483924     9.51860
# 9        0.8     VITA REALE         Lombardia    45.666667     ‎9.300
# 10       1.0     VITA REALE               Como   45.483924    ‎9.51860
# 11       0.5  VITA VIRTUALE               Como   45.483924     9.51860
# 12       0.1  VITA VIRTUALE             Varese   45.494800    8.492280
# 13       0.1     VITA REALE             Milano   45.283828    9.105340
# 14       0.1     VITA REALE             Torino     ‎45.413      7.4112
# 15       0.1     VITA REALE             Novara   45.262940     8.37444
# 16       0.5     VITA REALE             Torino     ‎45.413      7.4112
# 17       0.5     VITA REALE  Provincia di Como   45.483924     9.51860
# 18       1.0     VITA REALE            Ravenna    44.25444   12.115892
# 19       0.1  VITA VIRTUALE           Cagliari     39.1349        9.79
# 20       0.1  VITA VIRTUALE            Torino      ‎45.413      7.4112
# 21       0.1     VITA REALE             Torino     ‎45.413      7.4112
# 22       0.5     VITA REALE             Torino     ‎45.413      7.4112
# 23       0.8     VITA REALE           Calabria    38.64140   15.394356
# 24       0.1     VITA REALE             Torino     ‎45.413      7.4112
# 25       0.1     VITA REALE             Torino     ‎45.413      7.4112
# 26       0.1     VITA REALE           Piemonte  44.8992407   7.5673703
# 27       0.8     VITA REALE   Vallecrosia (IM)   44.211152    11.43048
# 28       0.1     VITA REALE             Torino     ‎45.413      7.4112
# 29       0.1     VITA REALE             Ragusa   36.554548    14.43480
# 30       0.1     VITA REALE            Torino      ‎45.413      7.4112
# 31       1.0     VITA REALE               Como   45.483924     9.51860
# 32       0.1     VITA REALE            Torino      ‎45.413      7.4112
# 33       0.1     VITA REALE               Como   45.483924     9.51860
# 34       0.1     VITA REALE               Como   45.483924     9.51860
# 35       0.5     VITA REALE             Milano   45.283828    9.105340

# %%
import numpy as np
import pandas as pd
import folium
from folium.plugins import HeatMap

# %%
lat=['40.395112',
'44.25444',
'44.25444',
'44.25444',
'44.25444',
'44.25444',
'45.4738',
'45.483924',
'45.483924',
'45.666667',
'45.483924',
'45.483924',
'45.494800',
'45.283828',
'45.07049',
'45.262940',
'45.07049',
'45.483924',
'44.25444',
'39.1349',
'45.07049',
'45.07049',
'45.07049',
'38.64140',
'45.07049',
'45.07049',
'44.8992407',
'44.211152',
'45.07049',
'36.554548',
'45.07049',
'45.483924',
'45.07049',
'45.483924',
'45.483924',
'45.283828'
            ]
lon=['14.481656',
'12.115892',
'12.115892',
'12.115892',
'12.115892',
'12.115892',
'9.10534',
'9.0832',
'9.51860',
'12.496365500000024', 
'9.0832',
'9.51860',
'8.492280',
'9.105340',
'7.4112',
'8.37444',
'7.4112',
'9.51860',
'12.115892',
'9.79',
'7.4112',
'7.4112',
'7.4112',
'15.394356',
'7.4112',
'7.4112',
'7.5673703',
'11.43048',
'7.4112',
'14.43480',
'7.4112',
'9.51860',
'7.4112',
'9.51860',
'9.51860',
'9.105340']

# %%
lat = lat.convert_objects(convert_numeric=True)
lat.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-8e3727c6edd2> in <module>
# ----> 1 lat = lat.convert_objects(convert_numeric=True)
#       2 lat.dtypes
#
# AttributeError: 'list' object has no attribute 'convert_objects'

# %%
location=[np.mean(df2.LATITUDINE.values), np.mean(df2.LONGITUDINE.values)]

# %%
map = folium.Map([41.89193,12.51133], zoom_start=6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
# minaccia       36 non-null float64
# MODALITA'      36 non-null object
# LOCALITA'      36 non-null object
# LATITUDINE     36 non-null object
# LONGITUDINE    36 non-null object
# dtypes: float64(1), object(4)
# memory usage: 1.5+ KB

# %%
df1 = df1.convert_objects(convert_numeric=True)
df1.dtypes
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# minaccia       float64
# MODALITA'       object
# LOCALITA'       object
# LATITUDINE     float64
# LONGITUDINE    float64
# dtype: object

# %%
df1
# Out:
#     minaccia      MODALITA'          LOCALITA'  LATITUDINE  LONGITUDINE
# 0        0.1     VITA REALE            Salerno   40.395112    14.481656
# 1        1.0     VITA REALE            Ravenna   44.254440    12.115892
# 2        1.0     VITA REALE            Ravenna   44.254440    12.115892
# 3        0.5     VITA REALE            Ravenna   44.254440    12.115892
# 4        0.1     VITA REALE            Ravenna   44.254440    12.115892
# 5        0.1  VITA VIRTUALE            Ravenna   44.254440    12.115892
# 6        0.1  VITA VIRTUALE             Lipomo   45.473800     9.105340
# 7        1.0     VITA REALE               Como   45.483924          NaN
# 8        0.1  VITA VIRTUALE               Como   45.483924     9.518600
# 9        0.8     VITA REALE         Lombardia    45.666667          NaN
# 10       1.0     VITA REALE               Como   45.483924          NaN
# 11       0.5  VITA VIRTUALE               Como   45.483924     9.518600
# 12       0.1  VITA VIRTUALE             Varese   45.494800     8.492280
# 13       0.1     VITA REALE             Milano   45.283828     9.105340
# 14       0.1     VITA REALE             Torino         NaN     7.411200
# 15       0.1     VITA REALE             Novara   45.262940     8.374440
# 16       0.5     VITA REALE             Torino         NaN     7.411200
# 17       0.5     VITA REALE  Provincia di Como   45.483924     9.518600
# 18       1.0     VITA REALE            Ravenna   44.254440    12.115892
# 19       0.1  VITA VIRTUALE           Cagliari   39.134900     9.790000
# 20       0.1  VITA VIRTUALE            Torino          NaN     7.411200
# 21       0.1     VITA REALE             Torino         NaN     7.411200
# 22       0.5     VITA REALE             Torino         NaN     7.411200
# 23       0.8     VITA REALE           Calabria   38.641400    15.394356
# 24       0.1     VITA REALE             Torino         NaN     7.411200
# 25       0.1     VITA REALE             Torino         NaN     7.411200
# 26       0.1     VITA REALE           Piemonte   44.899241     7.567370
# 27       0.8     VITA REALE   Vallecrosia (IM)   44.211152    11.430480
# 28       0.1     VITA REALE             Torino         NaN     7.411200
# 29       0.1     VITA REALE             Ragusa   36.554548    14.434800
# 30       0.1     VITA REALE            Torino          NaN     7.411200
# 31       1.0     VITA REALE               Como   45.483924     9.518600
# 32       0.1     VITA REALE            Torino          NaN     7.411200
# 33       0.1     VITA REALE               Como   45.483924     9.518600
# 34       0.1     VITA REALE               Como   45.483924     9.518600
# 35       0.5     VITA REALE             Milano   45.283828     9.105340

# %%
df1.dropna()
# Out:
#     minaccia      MODALITA'          LOCALITA'  LATITUDINE  LONGITUDINE
# 0        0.1     VITA REALE            Salerno   40.395112    14.481656
# 1        1.0     VITA REALE            Ravenna   44.254440    12.115892
# 2        1.0     VITA REALE            Ravenna   44.254440    12.115892
# 3        0.5     VITA REALE            Ravenna   44.254440    12.115892
# 4        0.1     VITA REALE            Ravenna   44.254440    12.115892
# 5        0.1  VITA VIRTUALE            Ravenna   44.254440    12.115892
# 6        0.1  VITA VIRTUALE             Lipomo   45.473800     9.105340
# 8        0.1  VITA VIRTUALE               Como   45.483924     9.518600
# 11       0.5  VITA VIRTUALE               Como   45.483924     9.518600
# 12       0.1  VITA VIRTUALE             Varese   45.494800     8.492280
# 13       0.1     VITA REALE             Milano   45.283828     9.105340
# 15       0.1     VITA REALE             Novara   45.262940     8.374440
# 17       0.5     VITA REALE  Provincia di Como   45.483924     9.518600
# 18       1.0     VITA REALE            Ravenna   44.254440    12.115892
# 19       0.1  VITA VIRTUALE           Cagliari   39.134900     9.790000
# 23       0.8     VITA REALE           Calabria   38.641400    15.394356
# 26       0.1     VITA REALE           Piemonte   44.899241     7.567370
# 27       0.8     VITA REALE   Vallecrosia (IM)   44.211152    11.430480
# 29       0.1     VITA REALE             Ragusa   36.554548    14.434800
# 31       1.0     VITA REALE               Como   45.483924     9.518600
# 33       0.1     VITA REALE               Como   45.483924     9.518600
# 34       0.1     VITA REALE               Como   45.483924     9.518600
# 35       0.5     VITA REALE             Milano   45.283828     9.105340

# %%
df2=df1.copy()

# %%
heatMap = HeatMap(zip(df2.LATITUDINE.values, df2.LONGITUDINE.values),
                   opacity=0.1,
                   max_val=1,
                   radius=12, blur=5,
                   max_zoom=1,
                   legend=True)

# %%
df2=df2.dropna(subset=['LATITUDINE'])

df2=df2.dropna(subset=['LONGITUDINE'])

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

# %%
map.add_child(heatMap,pop_up_text)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
