# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
df1=pd.read_csv('Sondaggio01.csv')

# %%
df1
# Out:
#      Informazioni cronologiche  minaccia      MODALITA'          LOCALITA'  \
# 0    2019/06/06 4:08:55 PM EET       0.1     VITA REALE            Salerno
# 1    2019/06/06 4:21:34 PM EET       1.0     VITA REALE            Ravenna
# 2    2019/06/06 4:22:23 PM EET       1.0     VITA REALE            Ravenna
# 3    2019/06/06 4:27:12 PM EET       0.5     VITA REALE            Ravenna
# 4    2019/06/06 5:36:57 PM EET       0.1     VITA REALE            Ravenna
# 5    2019/06/07 7:40:04 PM EET       0.1  VITA VIRTUALE            Ravenna
# 6    2019/06/08 9:20:43 AM EET       0.1  VITA VIRTUALE             Lipomo
# 7   2019/06/08 12:11:23 PM EET       1.0     VITA REALE               Como
# 8    2019/06/08 1:34:43 PM EET       0.1  VITA VIRTUALE               Como
# 9    2019/06/08 5:02:03 PM EET       0.8     VITA REALE         Lombardia
# 10   2019/06/08 5:11:36 PM EET       1.0     VITA REALE               Como
# ...

# %%
import numpy as np
import pandas as pd
import folium
from folium.plugins import HeatMap

# %%
lat=['40.395112',
'44.25444',
'44.25444',
'44.25444',
'44.25444',
'44.25444',
'45.4738',
'45.483924',
'45.483924',
'45.666667',
'45.483924',
'45.483924',
'45.494800',
'45.283828',
'45.07049',
'45.262940',
'45.07049',
'45.483924',
'44.25444',
'39.1349',
'45.07049',
'45.07049',
'45.07049',
'38.64140',
'45.07049',
'45.07049',
'44.8992407',
'44.211152',
'45.07049',
'36.554548',
'45.07049',
'45.483924',
'45.07049',
'45.483924',
'45.483924',
'45.283828'
            ]
lon=['14.481656',
'12.115892',
'12.115892',
'12.115892',
'12.115892',
'12.115892',
'9.10534',
'9.0832',
'9.51860',
'12.496365500000024', 
'9.0832',
'9.51860',
'8.492280',
'9.105340',
'7.4112',
'8.37444',
'7.4112',
'9.51860',
'12.115892',
'9.79',
'7.4112',
'7.4112',
'7.4112',
'15.394356',
'7.4112',
'7.4112',
'7.5673703',
'11.43048',
'7.4112',
'14.43480',
'7.4112',
'9.51860',
'7.4112',
'9.51860',
'9.51860',
'9.105340']

# %%
lat = lat.convert_objects(convert_numeric=True)
lat.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8e3727c6edd2> in <module>
# ----> 1 lat = lat.convert_objects(convert_numeric=True)
#       2 lat.dtypes
#
# AttributeError: 'list' object has no attribute 'convert_objects'

# %%
map = folium.Map([41.89193,12.51133], zoom_start=6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
# Informazioni cronologiche    36 non-null object
# minaccia                     36 non-null float64
# MODALITA'                    36 non-null object
# LOCALITA'                    36 non-null object
# LATITUDINE                   36 non-null object
# LONGITUDINE                  36 non-null object
# dtypes: float64(1), object(5)
# memory usage: 1.8+ KB

# %%
df1 = df1.convert_objects(convert_numeric=True)
df1.dtypes
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# Informazioni cronologiche     object
# minaccia                     float64
# MODALITA'                     object
# LOCALITA'                     object
# LATITUDINE                   float64
# LONGITUDINE                  float64
# dtype: object

# %%
df1
# Out:
#      Informazioni cronologiche  minaccia      MODALITA'          LOCALITA'  \
# 0    2019/06/06 4:08:55 PM EET       0.1     VITA REALE            Salerno
# 1    2019/06/06 4:21:34 PM EET       1.0     VITA REALE            Ravenna
# 2    2019/06/06 4:22:23 PM EET       1.0     VITA REALE            Ravenna
# 3    2019/06/06 4:27:12 PM EET       0.5     VITA REALE            Ravenna
# 4    2019/06/06 5:36:57 PM EET       0.1     VITA REALE            Ravenna
# 5    2019/06/07 7:40:04 PM EET       0.1  VITA VIRTUALE            Ravenna
# 6    2019/06/08 9:20:43 AM EET       0.1  VITA VIRTUALE             Lipomo
# 7   2019/06/08 12:11:23 PM EET       1.0     VITA REALE               Como
# 8    2019/06/08 1:34:43 PM EET       0.1  VITA VIRTUALE               Como
# 9    2019/06/08 5:02:03 PM EET       0.8     VITA REALE         Lombardia
# 10   2019/06/08 5:11:36 PM EET       1.0     VITA REALE               Como
# ...

# %%
df1.dropna()
# Out:
#     Informazioni cronologiche  minaccia      MODALITA'          LOCALITA'  \
# 0   2019/06/06 4:08:55 PM EET       0.1     VITA REALE            Salerno
# 1   2019/06/06 4:21:34 PM EET       1.0     VITA REALE            Ravenna
# 2   2019/06/06 4:22:23 PM EET       1.0     VITA REALE            Ravenna
# 3   2019/06/06 4:27:12 PM EET       0.5     VITA REALE            Ravenna
# 4   2019/06/06 5:36:57 PM EET       0.1     VITA REALE            Ravenna
# 5   2019/06/07 7:40:04 PM EET       0.1  VITA VIRTUALE            Ravenna
# 6   2019/06/08 9:20:43 AM EET       0.1  VITA VIRTUALE             Lipomo
# 8   2019/06/08 1:34:43 PM EET       0.1  VITA VIRTUALE               Como
# 11  2019/06/08 5:31:01 PM EET       0.5  VITA VIRTUALE               Como
# 12  2019/06/08 5:49:22 PM EET       0.1  VITA VIRTUALE             Varese
# 13  2019/06/08 5:59:26 PM EET       0.1     VITA REALE             Milano
# 15  2019/06/08 6:43:27 PM EET       0.1     VITA REALE             Novara
# ...

# %%
df2.rename(columns={'minaccia': 'Threat', "MODALITA'": 'real/virtual life', "LOCALITA'": 'places', "LATITUDINE'": 'lat', "LONGITUDINE'": 'lon'}, inplace=True)
df2
# Out:
#     Informazioni cronologiche  Threat real/virtual life             places  \
# 0   2019/06/06 4:08:55 PM EET     0.1        VITA REALE            Salerno
# 1   2019/06/06 4:21:34 PM EET     1.0        VITA REALE            Ravenna
# 2   2019/06/06 4:22:23 PM EET     1.0        VITA REALE            Ravenna
# 3   2019/06/06 4:27:12 PM EET     0.5        VITA REALE            Ravenna
# 4   2019/06/06 5:36:57 PM EET     0.1        VITA REALE            Ravenna
# 5   2019/06/07 7:40:04 PM EET     0.1     VITA VIRTUALE            Ravenna
# 6   2019/06/08 9:20:43 AM EET     0.1     VITA VIRTUALE             Lipomo
# 8   2019/06/08 1:34:43 PM EET     0.1     VITA VIRTUALE               Como
# 11  2019/06/08 5:31:01 PM EET     0.5     VITA VIRTUALE               Como
# 12  2019/06/08 5:49:22 PM EET     0.1     VITA VIRTUALE             Varese
# 13  2019/06/08 5:59:26 PM EET     0.1        VITA REALE             Milano
# ...

# %%
df2=df1.copy()

# %%
heatMap = HeatMap(zip(df2.LATITUDINE.values, df2.LONGITUDINE.values),
                   opacity=0.1,
                   max_val=1,
                   radius=12, blur=5,
                   max_zoom=1,
                   legend=True)

# %%
df2=df2.dropna(subset=['LATITUDINE'])

df2=df2.dropna(subset=['LONGITUDINE'])
df2
# Out:
#     Informazioni cronologiche  Threat real/virtual life             places  \
# 0   2019/06/06 4:08:55 PM EET     0.1        VITA REALE            Salerno
# 1   2019/06/06 4:21:34 PM EET     1.0        VITA REALE            Ravenna
# 2   2019/06/06 4:22:23 PM EET     1.0        VITA REALE            Ravenna
# 3   2019/06/06 4:27:12 PM EET     0.5        VITA REALE            Ravenna
# 4   2019/06/06 5:36:57 PM EET     0.1        VITA REALE            Ravenna
# 5   2019/06/07 7:40:04 PM EET     0.1     VITA VIRTUALE            Ravenna
# 6   2019/06/08 9:20:43 AM EET     0.1     VITA VIRTUALE             Lipomo
# 8   2019/06/08 1:34:43 PM EET     0.1     VITA VIRTUALE               Como
# 11  2019/06/08 5:31:01 PM EET     0.5     VITA VIRTUALE               Como
# 12  2019/06/08 5:49:22 PM EET     0.1     VITA VIRTUALE             Varese
# 13  2019/06/08 5:59:26 PM EET     0.1        VITA REALE             Milano
# ...

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
map.add_child(heatMap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
legend_elements = [Line2D([0], [0], color='b', lw=4, label='0.1 Threat'),
                   Line2D([0], [0], color='g', lw=4, label='0.5 Stalking'),
                   Line2D([0], [0], color='y', lw=4, label='0.8 Minace'),
                   Line2D([0], [0], color='r', lw=4, label='1 Abuse')]

# Create the figure
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='center')


plt.show()

# %%
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
